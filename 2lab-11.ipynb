# %% [markdown]
# __Лабораторная работа №2__\
# Задание 11

# %%
import numpy as np
from scipy.optimize import lsq_linear
A = np.array([[20, 15, 5],
              [10, 5, 2],
              [5, 10, 20]])
B = np.array([100, 50, 150])
bounds = (0, np.inf)
result = lsq_linear(A, B, bounds=bounds)
print("Решение (в сотнях граммов):", result.x)
print("Мясо: {:.1f} г".format(result.x[0] * 100))
print("Рыба: {:.1f} г".format(result.x[1] * 100))
print("Овощи: {:.1f} г".format(result.x[2] * 100))
# Out:
# Решение (в сотнях граммов): [3.40590980e+00 2.23396974e-17 6.64498798e+00]
# Мясо: 340.6 г
# Рыба: 0.0 г
# Овощи: 664.5 г
