# %% [markdown]
# __Лабораторная работа №2__

# %% [markdown]
# Задание 2

# %%
import numpy as np
arr = np.random.randint(1, 101, 20)
mask = arr % 5 == 0
print(arr[mask])
arr[mask] = -1
print(arr)
# Out:
# [90 50 80 10]
# [94 72 67 68 59 -1 -1 -1  2 97 79 36 93 64 58 23  9 -1 87 82]
