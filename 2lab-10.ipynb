# %% [markdown]
# __Лабораторная работа №2__\
# Задание 10

# %%
import numpy as np

A = np.array([[2, 3, -1],
              [4, -1, 2],
              [-3, 5, 4]])

B = np.array([5, 6, -2])

solution = np.linalg.solve(A, B)

print(solution)
# Out:
# [1.63963964 0.57657658 0.00900901]
